# %%
#Task 7.1.1
time_data = [
    (3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
    (4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
    (5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
    (3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
    (4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

low=[]
moderate=[]
high=[]

for i in time_data:
    if i[0] < 3:
        low.append(i[0])
    elif i[0] >= 3 and i[0] <= 5:
        moderate.append(i[0])
    else:
        high.append(i[0])

print("Low: ", low)
print("Moderate: ", moderate)
print("High: ", high)
# Out:
# Low:  [2.5, 1.5, 2.0, 2.5]
# Moderate:  [3.5, 5.0, 4.0, 3.0, 4.5, 3.0, 4.0, 5.0, 3.5]
# High:  [5.5, 6.0]

# %%
#Task 7.1.2

time_data = [
    (3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
    (4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
    (5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
    (3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
    (4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

low=[]
moderate=[]
high=[]

for i in time_data:
    if i[0] < 3:
        low.append(i[0])
    elif i[0] >= 3 and i[0] <= 5:
        moderate.append(i[0])
    else:
        high.append(i[0])

print("Number of low study time: ", len(low))
print("Number of moderate study time: ", len(moderate))
print("Number of high study time: ", len(high))
# Out:
# Number of low study time:  4
# Number of moderate study time:  9
# Number of high study time:  2

# %%
#Task 7.1.3

study_minutes = []

for i in time_data:
    minutes = i[0] * 60  # Study hours × 60
    study_minutes.append(minutes)

print("Study hours in minutes:", study_minutes)
# Out:
# Study hours in minutes: [210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]

# %%
# Task 7.1.4

study_hours = []
entertainment_hours = []
sleep_hours = []

for study, entertainment, sleep in time_data:
    study_hours.append(study)
    entertainment_hours.append(entertainment)
    sleep_hours.append(sleep)


avg_study = sum(study_hours) / len(study_hours)
avg_entertainment = sum(entertainment_hours) / len(entertainment_hours)
avg_sleep = sum(sleep_hours) / len(sleep_hours)

print(f"Average study hours: {avg_study:.2f}")
print(f"Average entertainment hours: {avg_entertainment:.2f}")
print(f"Average sleep hours: {avg_sleep:.2f}")
# Out:
# Average study hours: 3.70
# Average entertainment hours: 2.50
# Average sleep hours: 7.17

# %%
#Task 7.1.5

import matplotlib.pyplot as plt

plt.scatter(study_hours, sleep_hours, color='blue')
plt.xlabel("Study Hours")
plt.ylabel("Sleep Hours")
plt.title("Study vs Sleep Pattern")
plt.show()

# %%
# Task 8.1.1

def sum_nested_list(nested_list):
    total = 0
    for item in nested_list:
        if isinstance(item, list):  # If the item is a list, call the function recursively
            total += sum_nested_list(item)
        else:  # If it's a number, just add it to the total
            total += item
    return total

nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
result = sum_nested_list(nested_list)
print("Total sum:", result)
# Out:
# Total sum: 36

# %%
#Task 8.1.2

def generate_permutations(s):
    if len(s) == 1:
        return [s]

    permutations = []

    for i, char in enumerate(s):
        # Fix the current character and find permutations of the remaining string
        remaining = s[:i] + s[i+1:]
        for perm in generate_permutations(remaining):
            new_perm = char + perm
            if new_perm not in permutations:  # avoid duplicates
                permutations.append(new_perm)

    return permutations

print(generate_permutations("abc"))
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']

# %%
print(generate_permutations("aab"))
# Out:
# ['aab', 'aba', 'baa']

# %%
#Task 8.1.3

directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {
        "file3.txt": 400,
        "file4.txt": 100
    },
    "subdir2": {
        "subsubdir1": {
            "file5.txt": 250
        },
        "file6.txt": 150
    }
}

# Recursive function to calculate total size
def calculate_directory_size(directory):
    total_size = 0
    for key, value in directory.items():
        if isinstance(value, dict):
            total_size += calculate_directory_size(value)  # Recursive call for subdirectory
        else:
            total_size += value  # Add file size
    return total_size

total = calculate_directory_size(directory_structure)
print("Total directory size:", total, "KB")
# Out:
# Total directory size: 1400 KB

# %%
#Task 8.2.1

def min_coins(coins, amount):
    """
    Finds the minimum number of coins needed to make up a given amount using dynamic programming.

    Parameters:
    coins (list of int): A list of coin denominations (positive integers).
    amount (int): Target amount to make (non-negative integer).

    Returns:
    int: Minimum number of coins needed, or -1 if not possible.
    """
    # Initialize DP array: dp[i] = min coins to make amount i
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0  # 0 coins needed to make amount 0

    # Iterate over each coin
    for coin in coins:
        # Update dp table for amounts from coin to target amount
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)

    # If amount cannot be made, return -1
    return dp[amount] if dp[amount] != float('inf') else -1

coins = [1, 2, 5]
amount = 11

print("Minimum coins needed:", min_coins(coins, amount))
# Out:
# Minimum coins needed: 3

# %%
#Task 8.2.2

def longest_common_subsequence(s1, s2):
    """
    Finds the length of the longest common subsequence (LCS) of two strings.

    Parameters:
    s1 (str): First string
    s2 (str): Second string

    Returns:
    int: Length of the LCS
    """
    m, n = len(s1), len(s2)

    # Create DP table: (m+1) x (n+1), initialized to 0
    dp = [[0] * (n + 1) for _ in range(m + 1)]

    # Fill DP table
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1  # match found
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])  # no match

    return dp[m][n]  # LCS length

s1 = "abcde"
s2 = "ace"

print("Length of LCS:", longest_common_subsequence(s1, s2))
# Out:
# Length of LCS: 3

# %%
#Task 8.2.3

def knapsack(weights, values, capacity):
    """
    Solves the 0/1 Knapsack problem using dynamic programming.

    Parameters:
    weights (list of int): List of item weights
    values (list of int): List of item values
    capacity (int): Maximum weight capacity of the knapsack

    Returns:
    int: Maximum total value that can be carried within the given capacity
    """
    n = len(weights)

    # Create DP table: (n+1) x (capacity+1)
    dp = [[0] * (capacity + 1) for _ in range(n + 1)]

    # Fill the DP table
    for i in range(1, n + 1):
        for w in range(capacity + 1):
            if weights[i - 1] <= w:
                # Either include the item or skip it
                dp[i][w] = max(values[i - 1] + dp[i - 1][w - weights[i - 1]], dp[i - 1][w])
            else:
                # Cannot include the item
                dp[i][w] = dp[i - 1][w]

    return dp[n][capacity]

weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7

print("Maximum value:", knapsack(weights, values, capacity))
# Out:
# Maximum value: 9
